# %% [markdown]
# #**Hyperparameter Optimization with Keras**
# Finding the right hyperparameters for your deep learning model
#
# Very simple model: softmax classification

# %%
## STEP 1
# #This section is base copy from google's sample import of tensorflow, keras
# !pip install -q keras

# %%
## STEP 2 
#Here we connect to your google drive folder.
# And Generate auth tokens for Colab
# CLICK THE LINK GENERATED THEN COPY AND PASTE THE KEY INTO THE FIELD AND CLICK ENTER
from google.colab import drive
drive.mount('/content/drive')

# %%
# print 'Files in Drive:'
# !ls "/content/drive/My Drive/"

# %%
#Is GPU Working?
import tensorflow as tf
tf.test.gpu_device_name()

# %%
# Importing the Keras libraries and packages
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras import optimizers
import numpy as np
import matplotlib.pyplot as plt

# %%
# Let's load the MNIST dataset.
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# # Reshape data to fit model
X_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
X_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
# Conversion to float32 & Normalisation DATA
X_train= X_train.astype('float32')
X_test= X_test.astype('float32')
X_train = X_train/255
X_test = X_test/255
# # one-hot encoding:
Y_train_cat = to_categorical(y_train,num_classes = 10)
Y_test_cat = to_categorical(y_test,num_classes = 10)

# %% [markdown]
# ## ANN KERAS Model

# %%
# Choose the number for the hidden neurones
# Choose an activation function for the hidden layer: sigmoid, tanh or relu
activation = 'sigmoid'
# Initialising the CNN
model=Sequential()
# - Full connection
model.add(Flatten(input_shape = (28,28,1))) #  2D to 1D
#model.add(Dense(num_HN,activation = activation, kernel_initializer = "he_normal")) # hidden layer1
#model.add(Dense(num_HN,activation = activation, kernel_initializer = "he_normal")) # hidden layer2
model.add(Dense(10,activation = "softmax", kernel_initializer = "he_normal"))           # ouput layer
print(model.summary())

# %% [markdown]
# # COMPLING

# %%
opt = optimizers.SGD(lr = 0.003)#, momentum = 0.9, nesterov = True)
#opt = optimizers.Adam(lr = 0.003,decay = 1E-4)
model.compile(loss = "categorical_crossentropy",optimizer = opt, metrics = ['accuracy'])

# %% [markdown]
# # FITTING

# %%
batch_size = 100
epochs = 500

# Apprentissage du modèle
hist = model.fit(X_train,Y_train_cat,epochs = epochs,batch_size = batch_size,validation_data=(X_test, Y_test_cat), verbose=1)
model.save("/content/drive/My Drive/code workshop/model_mnist_5layer.h5")
model.save_weights("/content/drive/My Drive/code workshop/weightmodel_mnist_5layer.h5")
print("Saved model and weights")

# %% [markdown]
# # EVALUTE

# %%
score = model.evaluate(X_test, Y_test_cat,batch_size = 100)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# #Visualize Model Training History in Keras

# %%
#Graphiques  et  résultats
history_dict = hist.history
history_dict.keys()
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
acc = history_dict['acc']
val_acc = history_dict['val_acc'] #ce qui nous intéresse
epochs = range(1, len(acc) + 1)
#perte
plt.plot(epochs, loss_values, 'r-', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig("/content/drive/My Drive/workshop/Percep-Loss.png", bbox_inches="tight", dpi=600)
plt.show()
#précision
plt.clf()
plt.plot(epochs, acc, 'r-', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy FNN')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("/content/drive/My Drive/workshop/Percep-Accuracy.png", bbox_inches="tight", dpi=600)
plt.show()  #!!!!   affiche et remet à zéro => sauvegarder avant
